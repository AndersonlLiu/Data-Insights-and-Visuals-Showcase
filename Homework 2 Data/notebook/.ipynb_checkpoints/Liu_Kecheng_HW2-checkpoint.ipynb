# %%
import pandas as pd
import seaborn as seaborn
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import KNeighborsRegressor
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import math 
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. a). Download the data set

# %%
df = pd.read_excel('../CCPP/Folds5x2_pp.xlsx')
df
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %% [markdown]
# ### 1. b) Exploring the data

# %%
#return columns and rows number of data frame and answer the question of what they present
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
# AT    9568 non-null float64
# V     9568 non-null float64
# AP    9568 non-null float64
# RH    9568 non-null float64
# PE    9568 non-null float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %% [markdown]
# ### It has 5 columns and 9568 rows. It represent information of a power plant

# %%
#pairplot with scatter
seaborn.pairplot(df, kind = 'scatter')

# %% [markdown]
# ### My finding is there seldom graph has the linear relationship obviously

# %%
#find the statistic value of the data set
describe_df = df.describe()
describe_df.loc['range'] = describe_df.loc['max'] - describe_df.loc['min']
describe_df.loc['interquartile range'] = describe_df.loc['75%'] - describe_df.loc['25%']
describe_df
# Out:
#                               AT            V           AP           RH  \
# count                9568.000000  9568.000000  9568.000000  9568.000000
# mean                   19.651231    54.305804  1013.259078    73.308978
# std                     7.452473    12.707893     5.938784    14.600269
# min                     1.810000    25.360000   992.890000    25.560000
# 25%                    13.510000    41.740000  1009.100000    63.327500
# 50%                    20.345000    52.080000  1012.940000    74.975000
# 75%                    25.720000    66.540000  1017.260000    84.830000
# max                    37.110000    81.560000  1033.300000   100.160000
# range                  35.300000    56.200000    40.410000    74.600000
# interquartile range    12.210000    24.800000     8.160000    21.502500
#
#                               PE
# count                9568.000000
# mean                  454.365009
# std                    17.066995
# min                   420.260000
# ...

# %% [markdown]
# ### 1. c) fit a linear regression for each variable

# %%
X_AT = df['AT']
Y = df['PE']
X_AT = sm.add_constant(X_AT)
model_AT = sm.OLS(Y, X_AT).fit()
predictions = model_AT.predict(X_AT) 
print_model_AT = model_AT.summary()
print(print_model_AT)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                 8.510e+04
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):               0.00
# Time:                        23:44:08   Log-Likelihood:                -29756.
# No. Observations:                9568   AIC:                         5.952e+04
# Df Residuals:                    9566   BIC:                         5.953e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        497.0341      0.156   3177.280      0.000     496.727     497.341
# ...

# %%
#plot the diagram AT vs. PE
plt.scatter(df['AT'], df['PE'], color='red')
plt.title('AT Vs PE', fontsize=14)
plt.xlabel('AT', fontsize=14)
plt.ylabel('PE', fontsize=14)
plt.grid(True)
plt.show()

# %%
X_V = df['V']
X_V = sm.add_constant(X_V)
model_V = sm.OLS(Y, X_V).fit()
predictions = model_V.predict(X_V) 
print_model_V = model_V.summary()
print(print_model_V)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                 2.972e+04
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):               0.00
# Time:                        23:53:07   Log-Likelihood:                -33963.
# No. Observations:                9568   AIC:                         6.793e+04
# Df Residuals:                    9566   BIC:                         6.794e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        517.8015      0.378   1370.218      0.000     517.061     518.542
# ...

# %%
#plot the diagram V vs. PE
plt.scatter(df['V'], df['PE'], color='red')
plt.title('V Vs PE', fontsize=14)
plt.xlabel('V', fontsize=14)
plt.ylabel('PE', fontsize=14)
plt.grid(True)
plt.show()

# %%
X_AP = df['AP']
X_AP = sm.add_constant(X_AP)
model_AP = sm.OLS(Y, X_AP).fit()
predictions = model_AP.predict(X_AP) 
print_model_AP = model_AP.summary()
print(print_model_AP)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     3516.
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):               0.00
# Time:                        23:55:42   Log-Likelihood:                -39224.
# No. Observations:                9568   AIC:                         7.845e+04
# Df Residuals:                    9566   BIC:                         7.847e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1055.2610     25.459    -41.449      0.000   -1105.167   -1005.355
# ...

# %%
#plot the diagram AP vs. PE
plt.scatter(df['AP'], df['PE'], color='red')
plt.title('AP Vs PE', fontsize=14)
plt.xlabel('AP', fontsize=14)
plt.ylabel('PE', fontsize=14)
plt.grid(True)
plt.show()

# %%
X_RH = df['RH']
X_RH = sm.add_constant(X_RH)
model_RH = sm.OLS(Y, X_RH).fit()
predictions = model_RH.predict(X_RH) 
print_model_RH = model_RH.summary()
print(print_model_RH)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.152
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     1714.
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):               0.00
# Time:                        23:56:35   Log-Likelihood:                -39933.
# No. Observations:                9568   AIC:                         7.987e+04
# Df Residuals:                    9566   BIC:                         7.988e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        420.9618      0.823    511.676      0.000     419.349     422.574
# ...

# %%
#plot the diagram RH vs. PE
plt.scatter(df['RH'], df['PE'], color='red')
plt.title('RH Vs PE', fontsize=14)
plt.xlabel('RH', fontsize=14)
plt.ylabel('PE', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Due to all the p_value of the variables is 0, meaning they are all significant for the models. So I compare the R-squared of it. And it seems like AT has the stongest relationship with the result due to both the R-squared value and the graph

# %% [markdown]
# ### 1. d) multiple regression model

# %%
X = df[['AT', 'V', 'AP', 'RH']]
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Tue, 08 Feb 2022   Prob (F-statistic):               0.00
# Time:                        00:11:37   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# ...

# %% [markdown]
# ### The all variables reject the null hypothesis course their p-value are all 0

# %% [markdown]
# ### 1.e) ploting the coef

# %%
plt.scatter([-2.1713, -1.1681, 1.4899, 0.4557], model.params[1:5], color='red')
plt.title('simple linear regression coefficient Vs multiple linear regression coefficient', fontsize=14)
plt.xlabel('simple linear regression coefficient', fontsize=10)
plt.ylabel('multiple linear regression coefficient', fontsize=10)
plt.grid(True)
plt.show()

# %%
# Out:
# AT   -1.977513
# V    -0.233916
# AP    0.062083
# RH   -0.158054
# dtype: float64

# %% [markdown]
# ### 1. f) fit a polynomial equation

# %%
# applying polynomial regression degree 3
poly = PolynomialFeatures(degree = 3, include_bias = True)
x = df['AT'].to_numpy()
x = x.reshape(-1, 1)
x_poly = poly.fit_transform(x)
y = df['PE']
x_poly = sm.add_constant(x_poly)
model_AT_poly = sm.OLS(y, x_poly).fit()
predictions = model_AT_poly.predict(x_poly) 
print_model_AT_poly = model_AT_poly.summary()
print(print_model_AT_poly)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                 3.299e+04
# Date:                Tue, 08 Feb 2022   Prob (F-statistic):               0.00
# Time:                        17:51:22   Log-Likelihood:                -29101.
# No. Observations:                9568   AIC:                         5.821e+04
# Df Residuals:                    9564   BIC:                         5.824e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        492.7281      0.673    732.248      0.000     491.409     494.047
# ...

# %%
poly = PolynomialFeatures(degree = 3, include_bias = True)
x = df['V'].to_numpy()
x = x.reshape(-1, 1)
x_poly = poly.fit_transform(x)
y = df['PE']
x_poly = sm.add_constant(x_poly)
model_AT_poly = sm.OLS(y, x_poly).fit()
predictions = model_AT_poly.predict(x_poly) 
print_model_AT_poly = model_AT_poly.summary()
print(print_model_AT_poly)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                 1.098e+04
# Date:                Tue, 08 Feb 2022   Prob (F-statistic):               0.00
# Time:                        17:36:57   Log-Likelihood:                -33585.
# No. Observations:                9568   AIC:                         6.718e+04
# Df Residuals:                    9564   BIC:                         6.721e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        554.1468      9.151     60.557      0.000     536.209     572.084
# ...

# %%
poly = PolynomialFeatures(degree = 3, include_bias = True)
x = df['AP'].to_numpy()
x = x.reshape(-1, 1)
x_poly = poly.fit_transform(x)
y = df['PE']
x_poly = sm.add_constant(x_poly)
model_AT_poly = sm.OLS(y, x_poly).fit()
predictions = model_AT_poly.predict(x_poly) 
print_model_AT_poly = model_AT_poly.summary()
print(print_model_AT_poly)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     1813.
# Date:                Thu, 10 Feb 2022   Prob (F-statistic):               0.00
# Time:                        17:18:28   Log-Likelihood:                -39184.
# No. Observations:                9568   AIC:                         7.837e+04
# Df Residuals:                    9565   BIC:                         7.840e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0747      0.009      8.415      0.000       0.057       0.092
# ...

# %%
poly = PolynomialFeatures(degree = 3, include_bias = True)
x = df['RH'].to_numpy()
x = x.reshape(-1, 1)
x_poly = poly.fit_transform(x)
y = df['PE']
x_poly = sm.add_constant(x_poly)
model_AT_poly = sm.OLS(y, x_poly).fit()
predictions = model_AT_poly.predict(x_poly) 
print_model_AT_poly = model_AT_poly.summary()
print(print_model_AT_poly)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     579.2
# Date:                Tue, 08 Feb 2022   Prob (F-statistic):               0.00
# Time:                        17:37:40   Log-Likelihood:                -39923.
# No. Observations:                9568   AIC:                         7.985e+04
# Df Residuals:                    9564   BIC:                         7.988e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        468.4135     10.545     44.422      0.000     447.744     489.083
# ...

# %% [markdown]
# ### I think all the variables except "V" all display a nonlinear relationship with the response as the p-value all equal to 0

# %% [markdown]
# ### 1. g) Trying all the interaction

# %%
# make the new df with all the interactions
df_copy = df.copy()
df_copy['ATV'] = df_copy['AT'] * df_copy['V']
df_copy['ATAP'] = df_copy['AT'] * df_copy['AP']
df_copy['ATRH'] = df_copy['AT'] * df_copy['RH']
df_copy['VAP'] = df_copy['V'] * df_copy['AP']
df_copy['VRH'] = df_copy['V'] * df_copy['RH']
df_copy['APRH'] = df_copy['AP'] * df_copy['RH']

# %%
# doing the multiple regression with the new interaction variables
X_new = df_copy[['AT', 'V', 'AP', 'RH', 'ATV', 'ATAP', 'ATRH', 'VAP', 'VRH', 'APRH']]
X_new = sm.add_constant(X_new)
model = sm.OLS(Y, X_new).fit()
predictions = model.predict(X_new) 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                 1.405e+04
# Date:                Thu, 10 Feb 2022   Prob (F-statistic):               0.00
# Time:                        14:13:37   Log-Likelihood:                -27548.
# No. Observations:                9568   AIC:                         5.512e+04
# Df Residuals:                    9557   BIC:                         5.520e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        685.7825     78.640      8.721      0.000     531.631     839.934
# ...

# %% [markdown]
# ### From the result, AT * AP and V * RH are statiscally insignificant as the p_value > 0.05

# %% [markdown]
# ### 1. h)

# %%
# Split the data to 70% tain and 30% test
train_data_h, test_data_h = train_test_split(df_copy, test_size=0.3)
features = ['AT', 'V', 'AP', 'RH']
train_X_h = train_data_h[features]
train_y_h = train_data_h['PE']
test_X_h = test_data_h[features]
test_y_h = test_data_h['PE']

# %%
# did the regression with the 70% of data
train_X_h = sm.add_constant(train_X_h)
model_h = sm.OLS(train_y_h, train_X_h).fit()
test_X_h = sm.add_constant(test_X_h)
predictions = model_h.predict(test_X_h) 
print_model = model_h.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                 2.140e+04
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        00:06:31   Log-Likelihood:                -19716.
# No. Observations:                6697   AIC:                         3.944e+04
# Df Residuals:                    6692   BIC:                         3.948e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        446.5784     11.812     37.806      0.000     423.423     469.734
# ...

# %%
#Return the train and test MSE of spliting data
train_mse = mean_squared_error(train_y_h, model_h.predict(train_X_h))
print('The Train MSE is:', train_mse)
test_mse = mean_squared_error(test_y_h, model_h.predict(test_X_h))
print('The Test MSE is:', test_mse)
# Out:
# The Train MSE is: 21.120812717153836
# The Test MSE is: 19.950260691889596

# %%
train_formula = smf.ols("PE ~ AT + V + AP + RH + AT * V + AT * AP + AT * RH + V * AP + V * RH + AP * RH + np.power(AT,2) +  np.power(V,2) +  np.power(AP,2) +  np.power(RH,2)", data = df_copy).fit()
train_mse_ALL = mean_squared_error(train_y_h, train_formula.predict(train_X_h))
print('The Train MSE when adding all interactions and quadralic variables is:', train_mse_ALL)
test_mse_ALL = mean_squared_error(test_y_h, train_formula.predict(test_X_h))
print('The Test MSE when adding all interactions and quadralic variables is:', test_mse_ALL)
print(train_formula.summary())
# Out:
# The Train MSE when adding all interactions and quadralic variables is: 18.321792045746747
# The Test MSE when adding all interactions and quadralic variables is: 17.59314310400361
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.030e+04
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        10:34:52   Log-Likelihood:                -27431.
# No. Observations:                9568   AIC:                         5.489e+04
# Df Residuals:                    9553   BIC:                         5.500e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### From the summary table, we delete the insignificant terms AT * AP, V * AP, V * RH

# %%
#After removing all insignificant terms 
train_formula_new = smf.ols("PE ~ AT + V + AP + RH + AT * V + AT * RH + AP * RH + np.power(AT,2) +  np.power(AP,2) + np.power(V,2) +  np.power(RH,2)", data = df_copy).fit()
train_mse_ALL = mean_squared_error(train_y_h, train_formula_new.predict(train_X_h))
print('The Train MSE when adding all interactions and quadralic variables is:', train_mse_ALL)
test_mse_ALL = mean_squared_error(test_y_h, train_formula_new.predict(test_X_h))
print('The Test MSE when adding all interactions and quadralic variables is:', test_mse_ALL)
print(train_formula_new.summary())
# Out:
# The Train MSE when adding all interactions and quadralic variables is: 18.343466399054606
# The Test MSE when adding all interactions and quadralic variables is: 17.658665615926385
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.308e+04
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        10:39:49   Log-Likelihood:                -27440.
# No. Observations:                9568   AIC:                         5.490e+04
# Df Residuals:                    9556   BIC:                         5.499e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### 1. i) KNN Regression

# %%
# Split data into 80% train and 20% test
train_data, test_data = train_test_split(df, test_size=0.2)
features = ['AT', 'V', 'AP', 'RH']
train_X = train_data[features]
train_y = train_data['PE']
test_X = test_data[features]
test_y = test_data['PE']

# %%
#knn regression with raw feature
BestN = 0
LowestError = 1
TestErrorList = []
TrainErrorList = []
for n in range(1, 101):
    neigh = KNeighborsRegressor(n_neighbors = n)
    neigh.fit(train_X, train_y)
    test_error = 1 - neigh.score(test_X, test_y)
    if test_error < LowestError:
        LowestError = test_error
        BestN = n
    TestErrorList.append(test_error)
    TrainErrorList.append(1 - neigh.score(train_X, train_y))
print('Lowest Error is', LowestError)
print('Best N is', BestN)
# Out:
# Lowest Error is 0.05611720014380717
# Best N is 4

# %%
# print out the test MSE for knn at the best N
neigh_mse = KNeighborsRegressor(n_neighbors = 6)
neigh_mse.fit(train_X, train_y)
test_mse_knn = mean_squared_error(test_y, neigh_mse.predict(test_X))
print('The test MSE is', test_mse_knn)
# Out:
# The test MSE is 16.3417465096366

# %%
#Reverse the errorlist to fit the 1/k graph
TestErrorList.reverse()
TrainErrorList.reverse()

# %%
#ploting the train and test error
plt.figure(figsize=(12, 6))
plt.plot(np.arange(0.01, 1.01, 0.01), TestErrorList, color='red', linestyle='dashed', marker='o',
         markerfacecolor='black', markersize=9)
plt.plot(np.arange(0.01, 1.01, 0.01), TrainErrorList, color='blue', linestyle='dashed', marker='o',
         markerfacecolor='black', markersize=9)
plt.title('Test Error & Train Error vs. 1/k')
plt.xlabel('1/k')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
#Normalized data
x = df.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_new = pd.DataFrame(x_scaled)
df_new
# Out:
#              0         1         2         3         4
# 0     0.372521  0.291815  0.771591  0.638204  0.569536
# 1     0.662040  0.669039  0.671863  0.449330  0.319338
# 2     0.093484  0.249822  0.476862  0.892493  0.904636
# 3     0.539660  0.568683  0.429349  0.684718  0.347285
# 4     0.255241  0.216014  0.404355  0.952547  0.710464
# ...        ...       ...       ...       ...       ...
# 9563  0.420397  0.432918  0.522643  0.877212  0.526755
# 9564  0.322380  0.245907  0.761693  0.552547  0.653775
# 9565  0.835977  0.871352  0.495669  0.146381  0.123311
# 9566  0.642210  0.784520  0.518931  0.493700  0.205033
# 9567  0.560623  0.661210  0.602326  0.567158  0.437351
#
# [9568 rows x 5 columns]

# %%
# Split data into 80% train and 20% test for normalized data
train_data_Normalized, test_data_Normalized = train_test_split(df_new, test_size=0.2)
features = [0, 1, 2, 3]
train_X_Normalized = train_data_Normalized[features]
train_y_Normalized = train_data_Normalized[4]
test_X_Normalized = test_data_Normalized[features]
test_y_Normalized = test_data_Normalized[4]

# %%
#knn regression with normalized feature
BestN_Normalized = 0
LowestError_Normalized = 1
TestErrorList_Normalized = []
TrainErrorList_Normalized = []
for n in range(1, 101):
    neigh = KNeighborsRegressor(n_neighbors = n)
    neigh.fit(train_X_Normalized, train_y_Normalized)
    test_error = 1 - neigh.score(test_X_Normalized, test_y_Normalized)
    if test_error < LowestError_Normalized:
        LowestError_Normalized = test_error
        BestN_Normalized = n
    TestErrorList_Normalized.append(test_error)
    TrainErrorList_Normalized.append(1 - neigh.score(train_X_Normalized, train_y_Normalized))
print('Lowest Error for normalized features is', LowestError_Normalized)
print('Best N for normalized feature is', BestN_Normalized)
# Out:
# Lowest Error for normalized features is 0.04629484915155235
# Best N for normalized feature is 7

# %%
# print out the test MSE AFTER NORMALIZED for knn at the best N
neigh_mse_normalized = KNeighborsRegressor(n_neighbors = 4)
neigh_mse_normalized.fit(train_X_Normalized, train_y_Normalized)
test_mse_knn_normalized = mean_squared_error(test_y_Normalized, neigh_mse_normalized.predict(test_X_Normalized))
print('The test MSE after normalized is', test_mse_knn_normalized)
# Out:
# The test MSE after normalized is 0.002544031834292771

# %%
#Reverse the errorlist to fit the 1/k graph
TestErrorList_Normalized.reverse()
TrainErrorList_Normalized.reverse()

# %%
#ploting the train and test error for normalized data
plt.figure(figsize=(12, 6))
plt.plot(np.arange(0.01, 1.01, 0.01), TestErrorList_Normalized, color='red', linestyle='dashed', marker='o',
         markerfacecolor='black', markersize=9)
plt.plot(np.arange(0.01, 1.01, 0.01), TrainErrorList_Normalized, color='blue', linestyle='dashed', marker='o',
         markerfacecolor='black', markersize=9)
plt.title('Test Error & Train Error vs. 1/k for normalized data')
plt.xlabel('1/k')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# ### 1.j)

# %% [markdown]
# #### From the above calculation, it's obviously that the knn has the smaller msf than linear regression. I think the reason behind that is knn is a very flexible model which would do better when the feature is small and size of sample is large

# %% [markdown]
# ### 2.4.1 . For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.

# %% [markdown]
# #### a) When the sample size is large and the number of predictors is small, we may underfit the data if we decided to set a restricted assumption on it. On the contrary, using a flexible method would reduce the bias we get, and has a more accurate result.

# %% [markdown]
# #### b) When the number of predictors is large and the number of observations is small, using inflexible method would be better. Due to the small sample size, using a too flexible method may cause overfitting.

# %% [markdown]
# #### c) When the relationship is highly-nonlinear, it would be better using the inflexible method. Becasue non-linear machine learning model has low bias but high variance, we need to use a flexible method to find the correct fit

# %% [markdown]
# #### d) When the variance of the error term is extremely high, it's better to use inflexible method. Because a flexible method has a larger variance which would including a lot of noise terms.

# %% [markdown]
# ### 2.4.7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.

# %% [markdown]
# #### a) sqrt(0^2 + 3^2 + 0^2) = sqrt(9) = 3
# #### sqrt(2^2 + 0^2 + 0^2) = 2
# #### sqrt(0^2 + 1^2 + 3^2) = sqrt(1 + 9) = 3.16
# #### sqrt(0^2 + 1^2 + 2^2) = sqrt(1 + 4) = 2.23
# #### sqrt(0^2 + (-1)^2 + 1^2) = sqrt(2) = 1.41
# #### sqrt(1^2 + 1^2 + 1^2) = sqrt(3) = 1.73

# %% [markdown]
# #### b) For k = 1, the neareset point is at (-1, 0, 1), which is x5 and is a green one. So the result should be green

# %% [markdown]
# #### c) For k = 3, the nearest 3 points are point 2, 5, and 6. Among them,2 are red one. So the result should be red

# %% [markdown]
# #### d) As the K increasing, the model would be less flexible. In another word, it would be more similar to the linear regression. So for the case we have highly nonlinear relationships, a small k would be better.
