# %%
# Stock historical price
import requests
response = requests.get('https://api.stockdata.org/v1/data/eod?symbols=AAPL&api_token=jd0qoX9VUT5lMG5onfd3RBXzWEhXVKPwNz1Rheao')

# %%
import pandas as pd
js = response.json()
date = js.get('data')
stock_price = pd.DataFrame(columns = ['date', 'close_price'])
for i in date:
    stock_price_length = len(stock_price)
    stock_price.loc[stock_price_length] = [i['date'], i['close']]
stock_price
# Out:
#                             date  close_price
# 0    2022-04-21T16:00:00.000000Z       166.42
# 1    2022-04-20T16:00:00.000000Z       167.23
# 2    2022-04-19T16:00:00.000000Z       167.40
# 3    2022-04-18T16:00:00.000000Z       165.07
# 4    2022-04-14T16:00:00.000000Z       165.29
# ..                           ...          ...
# 247  2021-04-29T16:00:00.000000Z       133.48
# 248  2021-04-28T16:00:00.000000Z       133.58
# 249  2021-04-27T16:00:00.000000Z       134.39
# 250  2021-04-26T16:00:00.000000Z       134.72
# 251  2021-04-23T16:00:00.000000Z       134.32
#
# [252 rows x 2 columns]

# %%
import warnings
warnings.filterwarnings("ignore")
stock_price['date'] = stock_price['date'].str.replace('T16:00:00.000000Z', '')
stock_price = stock_price.sort_values(by=['date']).reset_index()
stock_price = stock_price.drop(['index'], axis = 1)
stock_price['pct_change'] = stock_price['close_price'].pct_change()
stock_price = stock_price.drop(0)
stock_price
# Out:
#            date  close_price  pct_change
# 1    2021-04-26       134.72    0.002978
# 2    2021-04-27       134.39   -0.002450
# 3    2021-04-28       133.58   -0.006027
# 4    2021-04-29       133.48   -0.000749
# 5    2021-04-30       131.46   -0.015133
# ..          ...          ...         ...
# 247  2022-04-14       165.29   -0.029988
# 248  2022-04-18       165.07   -0.001331
# 249  2022-04-19       167.40    0.014115
# 250  2022-04-20       167.23   -0.001016
# 251  2022-04-21       166.42   -0.004844
#
# [251 rows x 3 columns]

# %%
from pathlib import Path  
filepath = Path('DSCI510_final_project/data/Stock_Price.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
stock_price.to_csv(filepath)

# %%
# 10 year treasuty rate
import requests
from bs4 import BeautifulSoup

# %%
is_link = 'https://ycharts.com/indicators/10_year_treasury_rate'
response = requests.get(is_link)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
response_treasury = requests.get('https://data.nasdaq.com/api/v3/datasets/USTREASURY/YIELD.json?api_key=m4QDcyVZJxsukKV23FsE')

# %%
t_js = response_treasury.json()
t_data = t_js.get('dataset')['data']
t_price = pd.DataFrame(columns = ['date', 'close_price'])
for i in t_data:
    length = len(t_price)
    t_price.loc[length] = [i[0], i[10]]
t_price
# Out:
#             date  close_price
# 0     2022-02-04         1.93
# 1     2022-02-03         1.82
# 2     2022-02-02         1.78
# 3     2022-02-01         1.81
# 4     2022-01-31         1.79
# ...          ...          ...
# 8027  1990-01-08         8.02
# 8028  1990-01-05         7.99
# 8029  1990-01-04         7.98
# 8030  1990-01-03         7.99
# 8031  1990-01-02         7.94
#
# [8032 rows x 2 columns]

# %%
t_price = t_price[t_price['date'] > "2020-02-20"]
t_price['pct_change'] = t_price['close_price'].pct_change()
t_price = t_price.drop(0)

# %%
t_price
# Out:
#            date  close_price  pct_change
# 1    2022-02-03         1.82   -0.056995
# 2    2022-02-02         1.78   -0.021978
# 3    2022-02-01         1.81    0.016854
# 4    2022-01-31         1.79   -0.011050
# 5    2022-01-28         1.78   -0.005587
# ..          ...          ...         ...
# 487  2020-02-27         1.30    0.150442
# 488  2020-02-26         1.33    0.023077
# 489  2020-02-25         1.33    0.000000
# 490  2020-02-24         1.38    0.037594
# 491  2020-02-21         1.46    0.057971
#
# [491 rows x 3 columns]

# %%
filepath = Path('DSCI510_final_project/data/Treasury_Price.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
t_price.to_csv(filepath)

# %%
#https://data.nasdaq.com/data/USTREASURY/YIELD-treasury-yield-curve-rates
#https://stackoverflow.com/questions/29928982/how-do-i-convert-dates-from-month-dd-yy-to-mm-dd-yy-in-python

# %%
# Company News
from urllib.request import urlopen
from urllib.request import Request
finviz_url = 'https://finviz.com/quote.ashx?t=AAPL'
news_tables = {}
req = Request(url=finviz_url,headers={'user-agent': 'my-app/0.0.1'}) 
resp = urlopen(req)    
html = BeautifulSoup(resp, features="lxml")
news_table = html.find(id='news-table')
news_tables['AAPL'] = news_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kc/2xdp4p_n6bs5mdv6ynvvkcq00000gn/T/ipykernel_1402/1559015091.py in <module>
#       6 req = Request(url=finviz_url,headers={'user-agent': 'my-app/0.0.1'})
#       7 resp = urlopen(req)
# ----> 8 html = BeautifulSoup(resp, features="lxml")
#       9 news_table = html.find(id='news-table')
#      10 news_tables['AAPL'] = news_table
#
# NameError: name 'BeautifulSoup' is not defined

# %%
df = news_tables['AAPL']
df_tr = df.findAll('tr')
print ('\n')
print ('Recent News Headlines for {}: '.format('AAPL'))
for i, table_row in enumerate(df_tr):
    a_text = table_row.a.text
    td_text = table_row.td.text
    td_text = td_text.strip()
    print(a_text,'(',td_text,')')
# Out:
# Recent News Headlines for AAPL:
# Dow Jones Futures: Bears Hunt Down Market Bulls; What Investors Should Do Now ( Apr-22-22 08:07PM )
# Apple Is the Last FAANG Standing ( 07:58PM )
# Activision Union Bid Will Go to a Vote, Labor Board Orders ( 05:52PM )
# Tech companies gear up to report earnings next week ( 04:47PM )
# Whats driving the nationwide push for labor unionization ( 04:43PM )
# Apple Stock Called 'Good Hiding Place' In Volatile Market ( 04:05PM )
# Facebook Is Broken. Execs Say a Fix Wont Come Fast. ( 03:57PM )
# Unions push at Amazon, Apple and Starbucks could be most significant moment in the American labor movement in decades ( 03:56PM )
# Market sell-off indicates investors think the Fed is behind the curve: Strategist ( 03:34PM )
# Markets check: Stocks extend losses as Dow eyes worst day of 2022 ( 03:29PM )
# Apple gave investors more than $100 billion last year  how much more is coming? ( 03:13PM )
# Market check: Nasdaq turns red as Netflix, Tesla, Meta stocks drop ( 10:22AM )
# Samsung Galaxy buds live deal: Save £100 on the wireless earphones at Amazon ( 10:10AM )
# Wall Street rerates Netflix stock after surprise subscriber loss ( 10:00AM )
# Market check: Stocks open higher, Netflix stock craters, yields rise ( 09:57AM )
# Netflix stock plummets after first quarterly subscriber loss in 10 years ( 09:26AM )
# F5 Networks (FFIV) to Post Q2 Earnings: What's in Store? ( 08:27AM )
# Elon Musks Twitter Gambit Tees Up a Whos In-or-Out White Knight List ( 08:21AM )
# 3 Charts Showing How Top Stocks Have Performed After a Split ( 07:53AM )
# Netflix stock crashes; Co-CEO says company is working on fixing the problems ( 05:50AM )
# Global Smartphone Market Had Worst Drop Since Virus Outbreak ( Apr-19-22 11:20PM )
# How did Netflix lose subscribers in 2022? ( 06:50PM )
# Apple (AAPL) Gains But Lags Market: What You Should Know ( 05:45PM )
# Streaming: 61% of viewers believe their subscriptions are too expensive, report says ( 05:13PM )

# %%
parsed_news = []
for file_name, news_table in news_tables.items():
    for x in news_table.findAll('tr'):
        text = x.a.get_text() 
        date_scrape = x.td.text.split()

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        ticker = file_name.split('_')[0]
        
        parsed_news.append([ticker, date, time, text])

# %%
from datetime import datetime
news = pd.DataFrame(parsed_news, columns = ['Stock', 'Date', 'Time', 'News Headlines'])
news['Date'] = pd.to_datetime(news['Date'], format='%b-%d-%y')

# %%
news
# Out:
#    Stock       Date     Time  \
# 0   AAPL 2022-04-22  08:07PM
# 1   AAPL 2022-04-22  07:58PM
# 2   AAPL 2022-04-22  05:52PM
# 3   AAPL 2022-04-22  04:47PM
# 4   AAPL 2022-04-22  04:43PM
# ..   ...        ...      ...
# 95  AAPL 2022-04-20  05:50AM
# 96  AAPL 2022-04-19  11:20PM
# 97  AAPL 2022-04-19  06:50PM
# 98  AAPL 2022-04-19  05:45PM
# 99  AAPL 2022-04-19  05:13PM
#
#                                        News Headlines
# 0   Dow Jones Futures: Bears Hunt Down Market Bull...
# 1                    Apple Is the Last FAANG Standing
# 2   Activision Union Bid Will Go to a Vote, Labor ...
# 3   Tech companies gear up to report earnings next...
# 4   Whats driving the nationwide push for labor un...
# ..                                                ...
# 95  Netflix stock crashes; Co-CEO says company is ...
# 96  Global Smartphone Market Had Worst Drop Since ...
# 97          How did Netflix lose subscribers in 2022?
# 98  Apple (AAPL) Gains But Lags Market: What You S...
# 99  Streaming: 61% of viewers believe their subscr...
#
# [100 rows x 4 columns]

# %%
filepath = Path('DSCI510_final_project/data/News.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
news.to_csv(filepath)

# %%
news_tables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kc/2xdp4p_n6bs5mdv6ynvvkcq00000gn/T/ipykernel_1402/141368748.py in <module>
# ----> 1 news_tables
#
# NameError: name 'news_tables' is not defined
